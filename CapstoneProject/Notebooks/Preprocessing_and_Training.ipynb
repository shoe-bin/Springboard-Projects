# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#import the data and review features for incorrect datatypes or any additional cleanup
auto_df = pd.read_csv('../exports/subset_auto_data.csv')
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95226 entries, 0 to 95225
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    95226 non-null  int64
#  1   Date_start_contract   95226 non-null  object
#  2   Date_last_renewal     95226 non-null  object
#  3   Date_next_renewal     95226 non-null  object
#  4   Date_birth            95226 non-null  object
#  5   Date_driving_licence  95226 non-null  object
#  6   Distribution_channel  95226 non-null  int64
#  7   Seniority             95226 non-null  int64
#  8   Policies_in_force     95226 non-null  int64
#  9   Max_policies          95226 non-null  int64
#  10  Max_products          95226 non-null  int64
#  11  Lapse                 95226 non-null  int64
#  12  Payment               95226 non-null  int64
#  13  Premium               95226 non-null  float64
#  14  Cost_claims_year      95226 non-null  float64
#  15  N_claims_year         95226 non-null  int64
#  16  N_claims_history      95226 non-null  int64
#  17  R_Claims_history      95226 non-null  float64
#  18  Type_risk             95226 non-null  int64
#  19  Area                  95226 non-null  int64
#  20  Second_driver         95226 non-null  int64
#  21  Year_matriculation    95226 non-null  int64
#  22  Power                 95226 non-null  int64
#  23  Cylinder_capacity     95226 non-null  int64
#  24  Value_vehicle         95226 non-null  float64
#  25  N_doors               95226 non-null  int64
#  26  Type_fuel             95226 non-null  object
#  27  Length                95226 non-null  float64
#  28  Weight                95226 non-null  int64
#  29  Age                   95226 non-null  float64
# dtypes: float64(6), int64(18), object(6)
# memory usage: 21.8+ MB

# %%
#remove date columns as we have already pulled the relevant information from them (creating an age column based on the dates)
auto_df.drop(columns=['Date_start_contract', 'Date_last_renewal', 'Date_next_renewal', 'Date_birth', 'Date_driving_licence'], inplace=True)
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95226 entries, 0 to 95225
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    95226 non-null  int64
#  1   Distribution_channel  95226 non-null  int64
#  2   Seniority             95226 non-null  int64
#  3   Policies_in_force     95226 non-null  int64
#  4   Max_policies          95226 non-null  int64
#  5   Max_products          95226 non-null  int64
#  6   Lapse                 95226 non-null  int64
#  7   Payment               95226 non-null  int64
#  8   Premium               95226 non-null  float64
#  9   Cost_claims_year      95226 non-null  float64
#  10  N_claims_year         95226 non-null  int64
#  11  N_claims_history      95226 non-null  int64
#  12  R_Claims_history      95226 non-null  float64
#  13  Type_risk             95226 non-null  int64
#  14  Area                  95226 non-null  int64
#  15  Second_driver         95226 non-null  int64
#  16  Year_matriculation    95226 non-null  int64
#  17  Power                 95226 non-null  int64
#  18  Cylinder_capacity     95226 non-null  int64
#  19  Value_vehicle         95226 non-null  float64
#  20  N_doors               95226 non-null  int64
#  21  Type_fuel             95226 non-null  object
#  22  Length                95226 non-null  float64
#  23  Weight                95226 non-null  int64
#  24  Age                   95226 non-null  float64
# dtypes: float64(6), int64(18), object(1)
# memory usage: 18.2+ MB

# %%
#encode the Type of fuel which is a discrete categorical column to binary values of 0 or 1
mapping = {'D': 0, 'P' : 1}
auto_df['Type_fuel'] = auto_df['Type_fuel'].map(mapping)
auto_df['Type_fuel'].value_counts()
# Out:
# Type_fuel
# 0    63600
# 1    31626
# Name: count, dtype: int64

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95226 entries, 0 to 95225
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    95226 non-null  int64
#  1   Distribution_channel  95226 non-null  int64
#  2   Seniority             95226 non-null  int64
#  3   Policies_in_force     95226 non-null  int64
#  4   Max_policies          95226 non-null  int64
#  5   Max_products          95226 non-null  int64
#  6   Lapse                 95226 non-null  int64
#  7   Payment               95226 non-null  int64
#  8   Premium               95226 non-null  float64
#  9   Cost_claims_year      95226 non-null  float64
#  10  N_claims_year         95226 non-null  int64
#  11  N_claims_history      95226 non-null  int64
#  12  R_Claims_history      95226 non-null  float64
#  13  Type_risk             95226 non-null  int64
#  14  Area                  95226 non-null  int64
#  15  Second_driver         95226 non-null  int64
#  16  Year_matriculation    95226 non-null  int64
#  17  Power                 95226 non-null  int64
#  18  Cylinder_capacity     95226 non-null  int64
#  19  Value_vehicle         95226 non-null  float64
#  20  N_doors               95226 non-null  int64
#  21  Type_fuel             95226 non-null  int64
#  22  Length                95226 non-null  float64
#  23  Weight                95226 non-null  int64
#  24  Age                   95226 non-null  float64
# dtypes: float64(6), int64(19)
# memory usage: 18.2 MB

# %%
auto_df.head()
# Out:
#    ID  Distribution_channel  Seniority  Policies_in_force  Max_policies  \
# 0   3                     0         15                  1             2
# 1   3                     0         15                  1             2
# 2   3                     0         15                  1             2
# 3   3                     0         15                  1             2
# 4   6                     0         13                  1             2
#
#    Max_products  Lapse  Payment  Premium  Cost_claims_year  ...  \
# 0             1      0        0   380.20               0.0  ...
# 1             1      0        0   393.50               0.0  ...
# 2             1      0        0   393.50               0.0  ...
# 3             1      0        0   395.47               0.0  ...
# 4             2      0        0   250.52               0.0  ...
#
#    Second_driver  Year_matriculation  Power  Cylinder_capacity  Value_vehicle  \
# 0              0                2013     85               1229        16030.0
# 1              0                2013     85               1229        16030.0
# 2              0                2013     85               1229        16030.0
# 3              0                2013     85               1229        16030.0
# 4              0                2006     87               1598         9927.0
#
#    N_doors  Type_fuel  Length  Weight        Age
# 0        5          1   3.999    1105  40.700890
# 1        5          1   3.999    1105  41.702943
# 2        5          1   3.999    1105  42.702259
# 3        5          1   3.999    1105  43.701574
# 4        4          1   4.250    1055  49.604381
#
# [5 rows x 25 columns]

# %%
auto_df.corr()
# Out:
#                             ID  Distribution_channel  Seniority  \
# ID                    1.000000             -0.141352  -0.131236
# Distribution_channel -0.141352              1.000000  -0.154123
# Seniority            -0.131236             -0.154123   1.000000
# Policies_in_force    -0.041383             -0.034913   0.025876
# Max_policies         -0.072223             -0.066688   0.241914
# Max_products         -0.062136             -0.035902   0.221048
# Lapse                 0.026554              0.033192  -0.064314
# Payment               0.036552              0.044633  -0.171295
# Premium               0.018593              0.050479  -0.070993
# Cost_claims_year      0.010053              0.005359  -0.022670
# N_claims_year         0.003145              0.017065  -0.042144
# N_claims_history     -0.080885             -0.069397   0.447962
# R_Claims_history      0.022876              0.031934  -0.097525
# Type_risk            -0.004078             -0.023065  -0.009478
# Area                 -0.072440              0.095519   0.001672
# Second_driver        -0.050622              0.039099  -0.078553
# Year_matriculation   -0.002373              0.021067  -0.103561
# Power                 0.032966              0.005357  -0.061969
# Cylinder_capacity     0.039695              0.017564  -0.025191
# Value_vehicle         0.027341              0.005371  -0.058219
# N_doors               0.004226              0.009170  -0.043236
# Type_fuel            -0.038285             -0.030005   0.054761
# Length                0.041228              0.025189  -0.048144
# Weight                0.034695              0.018951  -0.044039
# Age                  -0.211144              0.014236   0.189730
#
#                       Policies_in_force  Max_policies  Max_products     Lapse  \
# ID                            -0.041383     -0.072223     -0.062136  0.026554
# Distribution_channel          -0.034913     -0.066688     -0.035902  0.033192
# Seniority                      0.025876      0.241914      0.221048 -0.064314
# Policies_in_force              1.000000      0.775061      0.057890  0.197834
# Max_policies                   0.775061      1.000000      0.262791  0.176415
# Max_products                   0.057890      0.262791      1.000000  0.015709
# Lapse                          0.197834      0.176415      0.015709  1.000000
# Payment                        0.050518      0.024031     -0.017660  0.073990
# Premium                       -0.050662     -0.037896     -0.012741  0.065049
# Cost_claims_year               0.018259      0.011065      0.000065 -0.010191
# N_claims_year                  0.200765      0.178803      0.015641 -0.011774
# N_claims_history               0.251340      0.430493      0.195637  0.087688
# R_Claims_history               0.110221      0.098039      0.004889  0.132827
# Type_risk                     -0.048665     -0.063262     -0.007340 -0.007406
# Area                          -0.045361     -0.032869      0.024453  0.034577
# Second_driver                  0.070416      0.039764     -0.003113 -0.015062
# Year_matriculation            -0.057969     -0.058188     -0.017774 -0.114471
# Power                          0.036666      0.047970      0.015312 -0.003849
# Cylinder_capacity              0.075918      0.087367      0.019306  0.051477
# Value_vehicle                  0.082588      0.087161      0.017073 -0.003142
# N_doors                       -0.022386     -0.026240      0.000332 -0.046332
# Type_fuel                     -0.029834     -0.031938      0.006552 -0.007886
# Length                         0.079602      0.092189      0.015271  0.016269
# Weight                         0.084252      0.095449      0.014075  0.010764
# Age                            0.028558      0.077750      0.082830 -0.024334
#
#                        Payment   Premium  Cost_claims_year  ...  \
# ID                    0.036552  0.018593          0.010053  ...
# Distribution_channel  0.044633  0.050479          0.005359  ...
# Seniority            -0.171295 -0.070993         -0.022670  ...
# Policies_in_force     0.050518 -0.050662          0.018259  ...
# Max_policies          0.024031 -0.037896          0.011065  ...
# Max_products         -0.017660 -0.012741          0.000065  ...
# Lapse                 0.073990  0.065049         -0.010191  ...
# Payment               1.000000  0.187958          0.028597  ...
# Premium               0.187958  1.000000          0.047511  ...
# Cost_claims_year      0.028597  0.047511          1.000000  ...
# N_claims_year         0.101238  0.069615          0.197479  ...
# N_claims_history      0.029168  0.085799          0.066646  ...
# R_Claims_history      0.141367  0.142677          0.169351  ...
# Type_risk             0.018846  0.012204         -0.000396  ...
# Area                  0.042264  0.083524          0.009096  ...
# Second_driver         0.029530  0.107512          0.010297  ...
# Year_matriculation    0.002497  0.287014          0.012815  ...
# Power                 0.036117  0.282626          0.019439  ...
# Cylinder_capacity     0.027865  0.123152          0.013736  ...
# Value_vehicle         0.021526  0.340708          0.022459  ...
# N_doors              -0.002354  0.030763         -0.006611  ...
# Type_fuel            -0.021840 -0.073945         -0.009033  ...
# Length                0.037889  0.195998          0.018452  ...
# Weight                0.030398  0.216801          0.018193  ...
# Age                  -0.129698 -0.101747         -0.021823  ...
#
#                       Second_driver  Year_matriculation     Power  \
# ID                        -0.050622           -0.002373  0.032966
# Distribution_channel       0.039099            0.021067  0.005357
# Seniority                 -0.078553           -0.103561 -0.061969
# Policies_in_force          0.070416           -0.057969  0.036666
# Max_policies               0.039764           -0.058188  0.047970
# Max_products              -0.003113           -0.017774  0.015312
# Lapse                     -0.015062           -0.114471 -0.003849
# Payment                    0.029530            0.002497  0.036117
# Premium                    0.107512            0.287014  0.282626
# Cost_claims_year           0.010297            0.012815  0.019439
# N_claims_year              0.024625           -0.020131  0.029237
# N_claims_history          -0.029214           -0.049761  0.038033
# R_Claims_history           0.030901           -0.035174  0.042672
# Type_risk                  0.089820            0.052539  0.080476
# Area                      -0.006569            0.020172 -0.006659
# Second_driver              1.000000            0.046275 -0.023525
# Year_matriculation         0.046275            1.000000  0.221245
# Power                     -0.023525            0.221245  1.000000
# Cylinder_capacity         -0.082896           -0.174601  0.541616
# Value_vehicle             -0.042183            0.215244  0.756270
# N_doors                    0.017736            0.209635 -0.051611
# Type_fuel                  0.029343           -0.072590 -0.116610
# Length                    -0.078192            0.068382  0.475443
# Weight                    -0.082681            0.100967  0.539211
# Age                        0.098943           -0.113501 -0.045212
#
#                       Cylinder_capacity  Value_vehicle   N_doors  Type_fuel  \
# ID                             0.039695       0.027341  0.004226  -0.038285
# Distribution_channel           0.017564       0.005371  0.009170  -0.030005
# Seniority                     -0.025191      -0.058219 -0.043236   0.054761
# Policies_in_force              0.075918       0.082588 -0.022386  -0.029834
# Max_policies                   0.087367       0.087161 -0.026240  -0.031938
# Max_products                   0.019306       0.017073  0.000332   0.006552
# Lapse                          0.051477      -0.003142 -0.046332  -0.007886
# Payment                        0.027865       0.021526 -0.002354  -0.021840
# Premium                        0.123152       0.340708  0.030763  -0.073945
# Cost_claims_year               0.013736       0.022459 -0.006611  -0.009033
# N_claims_year                  0.071382       0.049446 -0.019181  -0.051201
# N_claims_history               0.076284       0.056551 -0.039153  -0.050840
# R_Claims_history               0.084120       0.056592 -0.020708  -0.062897
# Type_risk                     -0.264161      -0.015258  0.012498   0.236161
# Area                          -0.026743      -0.010488 -0.021926   0.051304
# Second_driver                 -0.082896      -0.042183  0.017736   0.029343
# Year_matriculation            -0.174601       0.215244  0.209635  -0.072590
# Power                          0.541616       0.756270 -0.051611  -0.116610
# Cylinder_capacity              1.000000       0.655973 -0.100809  -0.402034
# Value_vehicle                  0.655973       1.000000 -0.025894  -0.259173
# N_doors                       -0.100809      -0.025894  1.000000  -0.110975
# Type_fuel                     -0.402034      -0.259173 -0.110975   1.000000
# Length                         0.635950       0.609033  0.007177  -0.304116
# Weight                         0.751867       0.723475  0.041182  -0.400849
# Age                            0.034829      -0.019120  0.018930   0.034619
#
#                         Length    Weight       Age
# ID                    0.041228  0.034695 -0.211144
# Distribution_channel  0.025189  0.018951  0.014236
# Seniority            -0.048144 -0.044039  0.189730
# Policies_in_force     0.079602  0.084252  0.028558
# Max_policies          0.092189  0.095449  0.077750
# Max_products          0.015271  0.014075  0.082830
# Lapse                 0.016269  0.010764 -0.024334
# Payment               0.037889  0.030398 -0.129698
# Premium               0.195998  0.216801 -0.101747
# Cost_claims_year      0.018452  0.018193 -0.021823
# N_claims_year         0.078105  0.071540 -0.038064
# N_claims_history      0.084404  0.080427  0.057373
# R_Claims_history      0.075315  0.073131 -0.064518
# Type_risk            -0.380859 -0.349044 -0.089237
# Area                 -0.010782 -0.018264 -0.026007
# Second_driver        -0.078192 -0.082681  0.098943
# Year_matriculation    0.068382  0.100967 -0.113501
# Power                 0.475443  0.539211 -0.045212
# Cylinder_capacity     0.635950  0.751867  0.034829
# Value_vehicle         0.609033  0.723475 -0.019120
# N_doors               0.007177  0.041182  0.018930
# Type_fuel            -0.304116 -0.400849  0.034619
# Length                1.000000  0.827145  0.009081
# Weight                0.827145  1.000000  0.010666
# Age                   0.009081  0.010666  1.000000
#
# [25 rows x 25 columns]

# %%
#Run describe to see the distribution of data to understand if scaling is needed
auto_df.describe()
# Out:
#                  ID  Distribution_channel     Seniority  Policies_in_force  \
# count  95226.000000          95226.000000  95226.000000       95226.000000
# mean   26561.150862              0.554218      6.655336           1.419654
# std    15350.049873              0.661895      6.212029           0.879651
# min        3.000000              0.000000      1.000000           1.000000
# 25%    13337.250000              0.000000      3.000000           1.000000
# 50%    26326.000000              0.000000      4.000000           1.000000
# 75%    40000.750000              1.000000      9.000000           2.000000
# max    53502.000000              3.000000     40.000000          17.000000
#
#        Max_policies  Max_products         Lapse       Payment       Premium  \
# count  95226.000000  95226.000000  95226.000000  95226.000000  95226.000000
# mean       1.795518      1.048128      0.219908      0.347384    333.527729
# std        1.108000      0.231117      0.460368      0.476142    134.341370
# min        1.000000      1.000000      0.000000      0.000000     40.400000
# 25%        1.000000      1.000000      0.000000      0.000000    254.810000
# 50%        1.000000      1.000000      0.000000      0.000000    301.650000
# 75%        2.000000      1.000000      0.000000      1.000000    370.710000
# max       17.000000      4.000000      7.000000      1.000000   2993.340000
#
#        Cost_claims_year  ...  Second_driver  Year_matriculation         Power  \
# count      95226.000000  ...   95226.000000        95226.000000  95226.000000
# mean         165.532681  ...       0.136265         2005.195587     99.341524
# std         1549.798278  ...       0.343072            5.678827     30.091550
# min            0.000000  ...       0.000000         1953.000000     12.000000
# 25%            0.000000  ...       0.000000         2002.000000     75.000000
# 50%            0.000000  ...       0.000000         2005.000000     98.000000
# 75%            0.000000  ...       0.000000         2008.000000    112.000000
# max       260853.240000  ...       1.000000         2018.000000    580.000000
#
#        Cylinder_capacity  Value_vehicle       N_doors     Type_fuel  \
# count       95226.000000   95226.000000  95226.000000  95226.000000
# mean         1719.102724   19551.297720      4.462720      0.332115
# std           409.410671    8219.591153      0.869386      0.470975
# min           125.000000     270.460000      0.000000      0.000000
# 25%          1422.000000   14270.080000      4.000000      0.000000
# 50%          1665.000000   18330.870000      5.000000      0.000000
# 75%          1956.000000   23000.000000      5.000000      1.000000
# max          6788.000000  220675.800000      6.000000      1.000000
#
#              Length        Weight           Age
# count  95226.000000  95226.000000  95226.000000
# mean       4.252007   1266.898137     47.177423
# std        0.393220    264.044713     12.790737
# min        1.978000    137.000000     18.075291
# 25%        3.999000   1089.000000     37.108830
# 50%        4.230000   1239.000000     46.600958
# 75%        4.443000   1399.000000     56.410678
# max        8.218000   5455.000000     98.529774
#
# [8 rows x 25 columns]

# %%
#realized I had an errant value in Distribution channel
#subset df to exclude category of 3 which was used to represent missing values
auto_df = auto_df[auto_df['Distribution_channel'] != 3]
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92194 entries, 0 to 95225
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    92194 non-null  int64
#  1   Distribution_channel  92194 non-null  int64
#  2   Seniority             92194 non-null  int64
#  3   Policies_in_force     92194 non-null  int64
#  4   Max_policies          92194 non-null  int64
#  5   Max_products          92194 non-null  int64
#  6   Lapse                 92194 non-null  int64
#  7   Payment               92194 non-null  int64
#  8   Premium               92194 non-null  float64
#  9   Cost_claims_year      92194 non-null  float64
#  10  N_claims_year         92194 non-null  int64
#  11  N_claims_history      92194 non-null  int64
#  12  R_Claims_history      92194 non-null  float64
#  13  Type_risk             92194 non-null  int64
#  14  Area                  92194 non-null  int64
#  15  Second_driver         92194 non-null  int64
#  16  Year_matriculation    92194 non-null  int64
#  17  Power                 92194 non-null  int64
#  18  Cylinder_capacity     92194 non-null  int64
#  19  Value_vehicle         92194 non-null  float64
#  20  N_doors               92194 non-null  int64
#  21  Type_fuel             92194 non-null  int64
#  22  Length                92194 non-null  float64
#  23  Weight                92194 non-null  int64
#  24  Age                   92194 non-null  float64
# dtypes: float64(6), int64(19)
# memory usage: 18.3 MB

# %%
#run describe again to confirm things are looking as they should.
auto_df.describe()
# Out:
#                  ID  Distribution_channel     Seniority  Policies_in_force  \
# count  92194.000000          92194.000000  92194.000000       92194.000000
# mean   27046.920429              0.473784      6.577673           1.417923
# std    15303.454875              0.499315      6.144852           0.877810
# min        3.000000              0.000000      1.000000           1.000000
# 25%    13846.500000              0.000000      3.000000           1.000000
# 50%    27237.000000              0.000000      4.000000           1.000000
# 75%    40446.000000              1.000000      9.000000           2.000000
# max    53502.000000              1.000000     40.000000          17.000000
#
#        Max_policies  Max_products         Lapse       Payment       Premium  \
# count  92194.000000  92194.000000  92194.000000  92194.000000  92194.000000
# mean       1.789173      1.047335      0.220882      0.349188    333.862704
# std        1.103817      0.229065      0.460588      0.476716    134.280356
# min        1.000000      1.000000      0.000000      0.000000     40.530000
# 25%        1.000000      1.000000      0.000000      0.000000    255.100000
# 50%        1.000000      1.000000      0.000000      0.000000    302.090000
# 75%        2.000000      1.000000      0.000000      1.000000    371.137500
# max       17.000000      4.000000      7.000000      1.000000   2993.340000
#
#        Cost_claims_year  ...  Second_driver  Year_matriculation         Power  \
# count      92194.000000  ...   92194.000000        92194.000000  92194.000000
# mean         167.190353  ...       0.136224         2005.202920     99.406057
# std         1572.591026  ...       0.343028            5.666898     30.059321
# min            0.000000  ...       0.000000         1953.000000     12.000000
# 25%            0.000000  ...       0.000000         2002.000000     75.000000
# 50%            0.000000  ...       0.000000         2005.000000     98.000000
# 75%            0.000000  ...       0.000000         2008.000000    112.000000
# max       260853.240000  ...       1.000000         2018.000000    580.000000
#
#        Cylinder_capacity  Value_vehicle       N_doors     Type_fuel  \
# count       92194.000000   92194.000000  92194.000000  92194.000000
# mean         1719.937881   19570.460070      4.462069      0.331052
# std           408.547611    8203.110028      0.870156      0.470594
# min           125.000000     270.460000      0.000000      0.000000
# 25%          1422.000000   14291.000000      4.000000      0.000000
# 50%          1685.000000   18340.000000      5.000000      0.000000
# 75%          1968.000000   23030.000000      5.000000      1.000000
# max          6788.000000  220675.800000      6.000000      1.000000
#
#              Length        Weight           Age
# count  92194.000000  92194.000000  92194.000000
# mean       4.253175   1267.699384     47.054487
# std        0.393921    263.699429     12.764341
# min        1.978000    137.000000     18.075291
# 25%        3.999000   1089.000000     37.021218
# 50%        4.235000   1240.000000     46.428474
# 75%        4.448000   1400.000000     56.243669
# max        8.218000   5455.000000     98.529774
#
# [8 rows x 25 columns]

# %%
#since you are just looking to predict passenger cars, lets subset the data by that risk type

# %%
auto_df_sub = auto_df[auto_df['Type_risk'] == 3]
auto_df_sub.drop(columns=['Type_risk'], inplace=True)
print(auto_df_sub['N_doors'].value_counts())
auto_df_sub.info()
# Out:
# N_doors
# 5    53758
# 3    13136
# 4    10863
# 2     1743
# 6       70
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 79570 entries, 0 to 95225
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    79570 non-null  int64
#  1   Distribution_channel  79570 non-null  int64
#  2   Seniority             79570 non-null  int64
#  3   Policies_in_force     79570 non-null  int64
#  4   Max_policies          79570 non-null  int64
#  5   Max_products          79570 non-null  int64
#  6   Lapse                 79570 non-null  int64
#  7   Payment               79570 non-null  int64
#  8   Premium               79570 non-null  float64
#  9   Cost_claims_year      79570 non-null  float64
#  10  N_claims_year         79570 non-null  int64
#  11  N_claims_history      79570 non-null  int64
#  12  R_Claims_history      79570 non-null  float64
#  13  Area                  79570 non-null  int64
#  14  Second_driver         79570 non-null  int64
#  15  Year_matriculation    79570 non-null  int64
#  16  Power                 79570 non-null  int64
#  17  Cylinder_capacity     79570 non-null  int64
#  18  Value_vehicle         79570 non-null  float64
#  19  N_doors               79570 non-null  int64
#  20  Type_fuel             79570 non-null  int64
#  21  Length                79570 non-null  float64
#  22  Weight                79570 non-null  int64
#  23  Age                   79570 non-null  float64
# dtypes: float64(6), int64(18)
# memory usage: 15.2 MB
# /var/folders/k7/_jdxw9bx3_7cybsnkxz0pr200000gn/T/ipykernel_1250/3806221671.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   auto_df_sub.drop(columns=['Type_risk'], inplace=True)

# %%
# Additionally, you will only be looking at cars with 4 or 5 doors (which would be either sedan or hatchbacks)
auto_df_sub = auto_df_sub[(auto_df_sub['N_doors'] == 4) | (auto_df_sub['N_doors'] == 5)]
auto_df_sub['N_doors'].value_counts()
# Out:
# N_doors
# 5    53758
# 4    10863
# Name: count, dtype: int64

# %%
auto_df_sub.corr()
# Out:
#                             ID  Distribution_channel  Seniority  \
# ID                    1.000000             -0.032234  -0.122575
# Distribution_channel -0.032234              1.000000  -0.280167
# Seniority            -0.122575             -0.280167   1.000000
# Policies_in_force    -0.045663             -0.056723   0.040362
# Max_policies         -0.076755             -0.125496   0.267334
# Max_products         -0.066490             -0.066324   0.222197
# Lapse                 0.028191              0.059692  -0.063754
# Payment               0.029619              0.086029  -0.163647
# Premium               0.004007              0.071059  -0.053930
# Cost_claims_year      0.009420              0.011430  -0.022894
# N_claims_year         0.001658              0.023917  -0.033675
# N_claims_history     -0.085962             -0.140471   0.474373
# R_Claims_history      0.020087              0.052134  -0.088013
# Area                 -0.084148              0.144717   0.007401
# Second_driver        -0.051039              0.057626  -0.076960
# Year_matriculation   -0.024025              0.022927  -0.073657
# Power                 0.031360              0.008903  -0.042850
# Cylinder_capacity     0.050535              0.016242  -0.026411
# Value_vehicle         0.026788              0.004151  -0.040631
# N_doors              -0.034606             -0.011407   0.006634
# Type_fuel            -0.045603             -0.045749   0.059204
# Length                0.053029              0.009949  -0.038498
# Weight                0.036978              0.004497  -0.035131
# Age                  -0.207231             -0.028744   0.179091
#
#                       Policies_in_force  Max_policies  Max_products     Lapse  \
# ID                            -0.045663     -0.076755     -0.066490  0.028191
# Distribution_channel          -0.056723     -0.125496     -0.066324  0.059692
# Seniority                      0.040362      0.267334      0.222197 -0.063754
# Policies_in_force              1.000000      0.770935      0.052147  0.171389
# Max_policies                   0.770935      1.000000      0.267565  0.156257
# Max_products                   0.052147      0.267565      1.000000  0.012313
# Lapse                          0.171389      0.156257      0.012313  1.000000
# Payment                        0.044945      0.017977     -0.013272  0.069387
# Premium                       -0.054152     -0.036930     -0.005058  0.066926
# Cost_claims_year               0.021712      0.012476      0.001987 -0.008506
# N_claims_year                  0.184548      0.161134      0.017870 -0.019845
# N_claims_history               0.244850      0.427933      0.199402  0.079907
# R_Claims_history               0.104730      0.092712      0.010089  0.139257
# Area                          -0.050953     -0.035946      0.031143  0.035457
# Second_driver                  0.080629      0.048058     -0.004064 -0.016449
# Year_matriculation            -0.051692     -0.045414     -0.011806 -0.115610
# Power                          0.028408      0.044586      0.024965 -0.001942
# Cylinder_capacity              0.056185      0.063579      0.022486  0.058984
# Value_vehicle                  0.075818      0.084392      0.026477  0.001022
# N_doors                       -0.039094     -0.041979     -0.004803 -0.040826
# Type_fuel                     -0.034525     -0.027347      0.009016 -0.021266
# Length                         0.036197      0.052217      0.024163  0.017422
# Weight                         0.054710      0.070177      0.021429  0.013710
# Age                            0.044434      0.087739      0.082574 -0.019197
#
#                        Payment   Premium  Cost_claims_year  ...  \
# ID                    0.029619  0.004007          0.009420  ...
# Distribution_channel  0.086029  0.071059          0.011430  ...
# Seniority            -0.163647 -0.053930         -0.022894  ...
# Policies_in_force     0.044945 -0.054152          0.021712  ...
# Max_policies          0.017977 -0.036930          0.012476  ...
# Max_products         -0.013272 -0.005058          0.001987  ...
# Lapse                 0.069387  0.066926         -0.008506  ...
# Payment               1.000000  0.174642          0.029381  ...
# Premium               0.174642  1.000000          0.046224  ...
# Cost_claims_year      0.029381  0.046224          1.000000  ...
# N_claims_year         0.099726  0.061342          0.219427  ...
# N_claims_history      0.020077  0.083271          0.069502  ...
# R_Claims_history      0.130465  0.127884          0.179125  ...
# Area                  0.036558  0.083163          0.007881  ...
# Second_driver         0.024759  0.109582          0.011899  ...
# Year_matriculation   -0.006941  0.288364          0.011911  ...
# Power                 0.019629  0.260006          0.013831  ...
# Cylinder_capacity     0.026384  0.105378          0.011439  ...
# Value_vehicle         0.009822  0.317765          0.017578  ...
# N_doors              -0.017437  0.010059          0.000135  ...
# Type_fuel            -0.027067 -0.073249         -0.011552  ...
# Length                0.034803  0.182998          0.015939  ...
# Weight                0.026098  0.223132          0.018799  ...
# Age                  -0.120105 -0.095490         -0.018018  ...
#
#                       Second_driver  Year_matriculation     Power  \
# ID                        -0.051039           -0.024025  0.031360
# Distribution_channel       0.057626            0.022927  0.008903
# Seniority                 -0.076960           -0.073657 -0.042850
# Policies_in_force          0.080629           -0.051692  0.028408
# Max_policies               0.048058           -0.045414  0.044586
# Max_products              -0.004064           -0.011806  0.024965
# Lapse                     -0.016449           -0.115610 -0.001942
# Payment                    0.024759           -0.006941  0.019629
# Premium                    0.109582            0.288364  0.260006
# Cost_claims_year           0.011899            0.011911  0.013831
# N_claims_year              0.023794           -0.029769  0.027069
# N_claims_history          -0.027016           -0.047576  0.038599
# R_Claims_history           0.028678           -0.051108  0.040205
# Area                      -0.008630            0.019913 -0.010487
# Second_driver              1.000000            0.035516 -0.040473
# Year_matriculation         0.035516            1.000000  0.184737
# Power                     -0.040473            0.184737  1.000000
# Cylinder_capacity         -0.069505           -0.213603  0.595917
# Value_vehicle             -0.051569            0.181325  0.758072
# N_doors                    0.026579            0.191531 -0.229143
# Type_fuel                  0.014766           -0.049413 -0.158876
# Length                    -0.072505            0.051299  0.618080
# Weight                    -0.069931            0.101648  0.665156
# Age                        0.115460           -0.109654 -0.023143
#
#                       Cylinder_capacity  Value_vehicle   N_doors  Type_fuel  \
# ID                             0.050535       0.026788 -0.034606  -0.045603
# Distribution_channel           0.016242       0.004151 -0.011407  -0.045749
# Seniority                     -0.026411      -0.040631  0.006634   0.059204
# Policies_in_force              0.056185       0.075818 -0.039094  -0.034525
# Max_policies                   0.063579       0.084392 -0.041979  -0.027347
# Max_products                   0.022486       0.026477 -0.004803   0.009016
# Lapse                          0.058984       0.001022 -0.040826  -0.021266
# Payment                        0.026384       0.009822 -0.017437  -0.027067
# Premium                        0.105378       0.317765  0.010059  -0.073249
# Cost_claims_year               0.011439       0.017578  0.000135  -0.011552
# N_claims_year                  0.057392       0.043320 -0.013686  -0.042681
# N_claims_history               0.056001       0.055900 -0.019576  -0.036217
# R_Claims_history               0.079072       0.050151 -0.025453  -0.058676
# Area                          -0.028708      -0.014829  0.010988   0.050737
# Second_driver                 -0.069505      -0.051569  0.026579   0.014766
# Year_matriculation            -0.213603       0.181325  0.191531  -0.049413
# Power                          0.595917       0.758072 -0.229143  -0.158876
# Cylinder_capacity              1.000000       0.697865 -0.239358  -0.397667
# Value_vehicle                  0.697865       1.000000 -0.206883  -0.296010
# N_doors                       -0.239358      -0.206883  1.000000   0.050114
# Type_fuel                     -0.397667      -0.296010  0.050114   1.000000
# Length                         0.632266       0.720407 -0.369000  -0.263918
# Weight                         0.737618       0.819056 -0.160960  -0.391944
# Age                            0.017157      -0.013741 -0.048526   0.071051
#
#                         Length    Weight       Age
# ID                    0.053029  0.036978 -0.207231
# Distribution_channel  0.009949  0.004497 -0.028744
# Seniority            -0.038498 -0.035131  0.179091
# Policies_in_force     0.036197  0.054710  0.044434
# Max_policies          0.052217  0.070177  0.087739
# Max_products          0.024163  0.021429  0.082574
# Lapse                 0.017422  0.013710 -0.019197
# Payment               0.034803  0.026098 -0.120105
# Premium               0.182998  0.223132 -0.095490
# Cost_claims_year      0.015939  0.018799 -0.018018
# N_claims_year         0.038955  0.049066 -0.031271
# N_claims_history      0.037561  0.054890  0.066461
# R_Claims_history      0.047645  0.056060 -0.054065
# Area                 -0.020378 -0.024616 -0.020611
# Second_driver        -0.072505 -0.069931  0.115460
# Year_matriculation    0.051299  0.101648 -0.109654
# Power                 0.618080  0.665156 -0.023143
# Cylinder_capacity     0.632266  0.737618  0.017157
# Value_vehicle         0.720407  0.819056 -0.013741
# N_doors              -0.369000 -0.160960 -0.048526
# Type_fuel            -0.263918 -0.391944  0.071051
# Length                1.000000  0.820497 -0.009396
# Weight                0.820497  1.000000 -0.012561
# Age                  -0.009396 -0.012561  1.000000
#
# [24 rows x 24 columns]

# %%
auto_df_sub.Premium.describe()
# Out:
# count    64621.000000
# mean       337.405497
# std        138.665053
# min         40.710000
# 25%        255.880000
# 50%        302.560000
# 75%        374.970000
# max       2993.340000
# Name: Premium, dtype: float64

# %%
test = auto_df_sub['Premium'].quantile([.05,.95])
print(test)
auto_df_sub[auto_df_sub['Premium'] > 498.80].shape
# Out:
# 0.05    202.96
# 0.95    598.68
# Name: Premium, dtype: float64
# (6462, 24)

# %%
cut_auto_df_sub = auto_df_sub[(auto_df_sub['Premium'] <= test[.95]) & (auto_df_sub['Premium'] >= test[.05])]
print(cut_auto_df_sub.shape)
cut_auto_df_sub.corr()
# Out:
# (58160, 24)
#                             ID  Distribution_channel  Seniority  \
# ID                    1.000000             -0.032803  -0.120961
# Distribution_channel -0.032803              1.000000  -0.281441
# Seniority            -0.120961             -0.281441   1.000000
# Policies_in_force    -0.042161             -0.056711   0.038277
# Max_policies         -0.073153             -0.129597   0.273030
# Max_products         -0.063847             -0.068790   0.218034
# Lapse                 0.029065              0.058272  -0.064780
# Payment               0.030573              0.083791  -0.165165
# Premium               0.027782              0.078334  -0.074925
# Cost_claims_year      0.009608              0.011241  -0.023553
# N_claims_year         0.003383              0.023182  -0.037553
# N_claims_history     -0.084756             -0.143897   0.474115
# R_Claims_history      0.021993              0.049228  -0.090725
# Area                 -0.085000              0.146048   0.006610
# Second_driver        -0.050121              0.052795  -0.075069
# Year_matriculation   -0.025692              0.016537  -0.070616
# Power                 0.034306              0.009244  -0.045725
# Cylinder_capacity     0.054258              0.016464  -0.029434
# Value_vehicle         0.030241              0.000808  -0.045126
# N_doors              -0.035733             -0.015421   0.007490
# Type_fuel            -0.047829             -0.048669   0.059789
# Length                0.054206              0.007756  -0.039151
# Weight                0.038379              0.001299  -0.037312
# Age                  -0.207169             -0.025958   0.173797
#
#                       Policies_in_force  Max_policies  Max_products     Lapse  \
# ID                            -0.042161     -0.073153     -0.063847  0.029065
# Distribution_channel          -0.056711     -0.129597     -0.068790  0.058272
# Seniority                      0.038277      0.273030      0.218034 -0.064780
# Policies_in_force              1.000000      0.759481      0.050573  0.183247
# Max_policies                   0.759481      1.000000      0.271317  0.162269
# Max_products                   0.050573      0.271317      1.000000  0.011638
# Lapse                          0.183247      0.162269      0.011638  1.000000
# Payment                        0.060584      0.025985     -0.011999  0.066557
# Premium                       -0.013779     -0.016665     -0.022888  0.067608
# Cost_claims_year               0.021719      0.011975     -0.002370 -0.007321
# N_claims_year                  0.188199      0.161531      0.013177 -0.018576
# N_claims_history               0.251868      0.436281      0.194314  0.082551
# R_Claims_history               0.112826      0.096334      0.004422  0.139299
# Area                          -0.050922     -0.038142      0.030198  0.032272
# Second_driver                  0.089098      0.052266     -0.005390 -0.020372
# Year_matriculation            -0.046625     -0.038149     -0.015978 -0.120243
# Power                          0.030014      0.047440      0.025705 -0.005800
# Cylinder_capacity              0.061817      0.067459      0.024119  0.057750
# Value_vehicle                  0.084297      0.092614      0.024406 -0.002933
# N_doors                       -0.040015     -0.042007     -0.008158 -0.038635
# Type_fuel                     -0.033916     -0.027571      0.007305 -0.020275
# Length                         0.040912      0.055618      0.024791  0.014397
# Weight                         0.062838      0.076576      0.021360  0.010337
# Age                            0.042242      0.086408      0.081926 -0.018212
#
#                        Payment   Premium  Cost_claims_year  ...  \
# ID                    0.030573  0.027782          0.009608  ...
# Distribution_channel  0.083791  0.078334          0.011241  ...
# Seniority            -0.165165 -0.074925         -0.023553  ...
# Policies_in_force     0.060584 -0.013779          0.021719  ...
# Max_policies          0.025985 -0.016665          0.011975  ...
# Max_products         -0.011999 -0.022888         -0.002370  ...
# Lapse                 0.066557  0.067608         -0.007321  ...
# Payment               1.000000  0.202832          0.029098  ...
# Premium               0.202832  1.000000          0.029622  ...
# Cost_claims_year      0.029098  0.029622          1.000000  ...
# N_claims_year         0.104794  0.057287          0.205090  ...
# N_claims_history      0.019628  0.051782          0.061641  ...
# R_Claims_history      0.130471  0.115016          0.169154  ...
# Area                  0.035005  0.076272          0.005927  ...
# Second_driver         0.018743  0.127392          0.009869  ...
# Year_matriculation   -0.018541  0.253571          0.005216  ...
# Power                 0.016696  0.203327          0.006116  ...
# Cylinder_capacity     0.025245  0.073609          0.007157  ...
# Value_vehicle         0.007037  0.246747          0.009329  ...
# N_doors              -0.021120  0.003312         -0.000980  ...
# Type_fuel            -0.022815 -0.074472         -0.009871  ...
# Length                0.030841  0.153309          0.011124  ...
# Weight                0.019905  0.182306          0.013253  ...
# Age                  -0.119888 -0.115170         -0.016775  ...
#
#                       Second_driver  Year_matriculation     Power  \
# ID                        -0.050121           -0.025692  0.034306
# Distribution_channel       0.052795            0.016537  0.009244
# Seniority                 -0.075069           -0.070616 -0.045725
# Policies_in_force          0.089098           -0.046625  0.030014
# Max_policies               0.052266           -0.038149  0.047440
# Max_products              -0.005390           -0.015978  0.025705
# Lapse                     -0.020372           -0.120243 -0.005800
# Payment                    0.018743           -0.018541  0.016696
# Premium                    0.127392            0.253571  0.203327
# Cost_claims_year           0.009869            0.005216  0.006116
# N_claims_year              0.024256           -0.037896  0.016657
# N_claims_history          -0.024968           -0.059768  0.022355
# R_Claims_history           0.025687           -0.066659  0.027072
# Area                      -0.009644            0.013736 -0.024616
# Second_driver              1.000000            0.025193 -0.046375
# Year_matriculation         0.025193            1.000000  0.155842
# Power                     -0.046375            0.155842  1.000000
# Cylinder_capacity         -0.071416           -0.241519  0.581446
# Value_vehicle             -0.058647            0.148407  0.743764
# N_doors                    0.025941            0.188678 -0.238003
# Type_fuel                  0.017848           -0.038491 -0.157744
# Length                    -0.078148            0.021537  0.616024
# Weight                    -0.075939            0.069908  0.655983
# Age                        0.113881           -0.103262 -0.026506
#
#                       Cylinder_capacity  Value_vehicle   N_doors  Type_fuel  \
# ID                             0.054258       0.030241 -0.035733  -0.047829
# Distribution_channel           0.016464       0.000808 -0.015421  -0.048669
# Seniority                     -0.029434      -0.045126  0.007490   0.059789
# Policies_in_force              0.061817       0.084297 -0.040015  -0.033916
# Max_policies                   0.067459       0.092614 -0.042007  -0.027571
# Max_products                   0.024119       0.024406 -0.008158   0.007305
# Lapse                          0.057750      -0.002933 -0.038635  -0.020275
# Payment                        0.025245       0.007037 -0.021120  -0.022815
# Premium                        0.073609       0.246747  0.003312  -0.074472
# Cost_claims_year               0.007157       0.009329 -0.000980  -0.009871
# N_claims_year                  0.050701       0.034299 -0.012619  -0.040270
# N_claims_history               0.045278       0.037908 -0.018162  -0.032446
# R_Claims_history               0.071412       0.036950 -0.024860  -0.054690
# Area                          -0.039801      -0.036181  0.013980   0.052269
# Second_driver                 -0.071416      -0.058647  0.025941   0.017848
# Year_matriculation            -0.241519       0.148407  0.188678  -0.038491
# Power                          0.581446       0.743764 -0.238003  -0.157744
# Cylinder_capacity              1.000000       0.692254 -0.240979  -0.405942
# Value_vehicle                  0.692254       1.000000 -0.220627  -0.307700
# N_doors                       -0.240979      -0.220627  1.000000   0.051028
# Type_fuel                     -0.405942      -0.307700  0.051028   1.000000
# Length                         0.629160       0.726028 -0.378221  -0.259397
# Weight                         0.735341       0.819328 -0.166980  -0.394827
# Age                            0.012588      -0.018002 -0.044593   0.071986
#
#                         Length    Weight       Age
# ID                    0.054206  0.038379 -0.207169
# Distribution_channel  0.007756  0.001299 -0.025958
# Seniority            -0.039151 -0.037312  0.173797
# Policies_in_force     0.040912  0.062838  0.042242
# Max_policies          0.055618  0.076576  0.086408
# Max_products          0.024791  0.021360  0.081926
# Lapse                 0.014397  0.010337 -0.018212
# Payment               0.030841  0.019905 -0.119888
# Premium               0.153309  0.182306 -0.115170
# Cost_claims_year      0.011124  0.013253 -0.016775
# N_claims_year         0.031389  0.041737 -0.031440
# N_claims_history      0.024800  0.038319  0.063956
# R_Claims_history      0.037361  0.043800 -0.053215
# Area                 -0.032338 -0.039181 -0.021219
# Second_driver        -0.078148 -0.075939  0.113881
# Year_matriculation    0.021537  0.069908 -0.103262
# Power                 0.616024  0.655983 -0.026506
# Cylinder_capacity     0.629160  0.735341  0.012588
# Value_vehicle         0.726028  0.819328 -0.018002
# N_doors              -0.378221 -0.166980 -0.044593
# Type_fuel            -0.259397 -0.394827  0.071986
# Length                1.000000  0.816450 -0.008381
# Weight                0.816450  1.000000 -0.012897
# Age                  -0.008381 -0.012897  1.000000
#
# [24 rows x 24 columns]

# %%
cut_auto_df_sub.describe()
# Out:
#                  ID  Distribution_channel     Seniority  Policies_in_force  \
# count  58160.000000          58160.000000  58160.000000       58160.000000
# mean   27303.032325              0.472060      6.387895           1.372558
# std    15290.867870              0.499223      6.068774           0.803856
# min        3.000000              0.000000      1.000000           1.000000
# 25%    14182.000000              0.000000      2.000000           1.000000
# 50%    27504.000000              0.000000      4.000000           1.000000
# 75%    40716.000000              1.000000      8.000000           2.000000
# max    53502.000000              1.000000     40.000000          16.000000
#
#        Max_policies  Max_products         Lapse       Payment       Premium  \
# count  58160.000000  58160.000000  58160.000000  58160.000000  58160.000000
# mean       1.739305      1.045839      0.215715      0.359732    323.405980
# std        1.037174      0.224062      0.447748      0.479926     85.332321
# min        1.000000      1.000000      0.000000      0.000000    202.960000
# 25%        1.000000      1.000000      0.000000      0.000000    260.270000
# 50%        1.000000      1.000000      0.000000      0.000000    302.555000
# 75%        2.000000      1.000000      0.000000      1.000000    364.745000
# max       17.000000      4.000000      5.000000      1.000000    598.680000
#
#        Cost_claims_year  ...  Second_driver  Year_matriculation         Power  \
# count      58160.000000  ...   58160.000000        58160.000000  58160.000000
# mean         153.478819  ...       0.146217         2005.556482    100.567056
# std         1429.256498  ...       0.353327            5.377061     27.848077
# min            0.000000  ...       0.000000         1953.000000     25.000000
# 25%            0.000000  ...       0.000000         2002.000000     80.000000
# 50%            0.000000  ...       0.000000         2005.000000    100.000000
# 75%            0.000000  ...       0.000000         2009.000000    114.000000
# max       236285.180000  ...       1.000000         2018.000000    580.000000
#
#        Cylinder_capacity  Value_vehicle       N_doors     Type_fuel  \
# count       58160.000000   58160.000000  58160.000000  58160.000000
# mean         1685.109044   19592.972126      4.830055      0.337208
# std           369.723736    7475.073580      0.375588      0.472761
# min           400.000000     270.460000      4.000000      0.000000
# 25%          1399.000000   14606.000000      5.000000      0.000000
# 50%          1598.000000   18450.000000      5.000000      0.000000
# 75%          1896.000000   22850.000000      5.000000      1.000000
# max          5967.000000  129040.000000      5.000000      1.000000
#
#              Length        Weight           Age
# count  58160.000000  58160.000000  58160.000000
# mean       4.230295   1245.692074     46.977918
# std        0.298047    216.782522     12.647310
# min        1.978000    349.000000     18.135524
# 25%        4.020000   1090.000000     37.012320
# 50%        4.249000   1232.000000     46.260096
# 75%        4.436000   1371.000000     56.019849
# max        5.260000   2643.000000     98.529774
#
# [8 rows x 24 columns]

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
#create the X and Y variables for your training and testing
X = auto_df_sub.drop(columns=['Premium'])
X = sm.add_constant(X)
y = auto_df_sub['Premium']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=47)

# %%
#run an OLS model without scaling the data to see what the initial prediction is with all features
model1 = sm.OLS(y_train, X_train)

model1_res = model1.fit()

model1_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Premium   R-squared:                       0.242
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     672.5
# Date:                Thu, 05 Sep 2024   Prob (F-statistic):               0.00
# Time:                        09:11:39   Log-Likelihood:            -3.0104e+05
# No. Observations:               48465   AIC:                         6.021e+05
# Df Residuals:                   48441   BIC:                         6.023e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -9364.3759    245.470    -38.149      0.000   -9845.500   -8883.252
# ID                    4.896e-06   3.71e-05      0.132      0.895   -6.78e-05    7.76e-05
# Distribution_channel     9.8386      1.167      8.433      0.000       7.552      12.125
# Seniority                0.1555      0.117      1.324      0.185      -0.075       0.386
# Policies_in_force      -14.4047      1.105    -13.031      0.000     -16.571     -12.238
# Max_policies            -4.7617      0.956     -4.979      0.000      -6.636      -2.887
# Max_products            -5.2929      2.590     -2.043      0.041     -10.370      -0.216
# Lapse                   27.7936      1.291     21.525      0.000      25.263      30.325
# Payment                 43.7661      1.181     37.054      0.000      41.451      46.081
# Cost_claims_year         0.0014      0.000      3.917      0.000       0.001       0.002
# N_claims_year           -2.8101      0.673     -4.176      0.000      -4.129      -1.491
# N_claims_history         3.4851      0.207     16.856      0.000       3.080       3.890
# R_Claims_history        13.9559      1.009     13.837      0.000      11.979      15.933
# Area                    15.4830      1.267     12.216      0.000      12.999      17.967
# Second_driver           48.9574      1.583     30.924      0.000      45.854      52.060
# Year_matriculation       4.8203      0.122     39.363      0.000       4.580       5.060
# Power                    0.1589      0.030      5.243      0.000       0.099       0.218
# Cylinder_capacity       -0.0368      0.003    -13.792      0.000      -0.042      -0.032
# Value_vehicle            0.0064      0.000     44.280      0.000       0.006       0.007
# N_doors                  6.5349      1.696      3.853      0.000       3.211       9.859
# Type_fuel                1.5062      1.335      1.129      0.259      -1.110       4.122
# Length                 -14.7268      3.555     -4.142      0.000     -21.695      -7.758
# Weight                  -0.0074      0.006     -1.231      0.218      -0.019       0.004
# Age                     -0.5883      0.046    -12.843      0.000      -0.678      -0.499
# ==============================================================================
# Omnibus:                    29238.208   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           696451.825
# Skew:                           2.474   Prob(JB):                         0.00
# Kurtosis:                      20.900   Cond. No.                     1.63e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <h1> MODEL 2

# %%
#recreate X and y, but scale before adding a constant to see if the results change at all
X = auto_df_sub.drop(columns=['Premium'])
y = auto_df_sub['Premium']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=47)

# %%
#Scale the X data for model preparation
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#add a constant to both the X_train_scaled and X_test_scaled variables to rerun the OLS model
X_train_scaled = sm.add_constant(X_train_scaled)
X_test_scaled = sm.add_constant(X_test_scaled)

# %%
#train a model on the dataset with the constant
model2 = sm.OLS(y_train, X_train_scaled)
model2_res = model2.fit()

model2_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Premium   R-squared:                       0.242
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     672.5
# Date:                Thu, 05 Sep 2024   Prob (F-statistic):               0.00
# Time:                        10:55:01   Log-Likelihood:            -3.0104e+05
# No. Observations:               48465   AIC:                         6.021e+05
# Df Residuals:                   48441   BIC:                         6.023e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        336.9329      0.548    614.897      0.000     335.859     338.007
# x1             0.0750      0.568      0.132      0.895      -1.039       1.189
# x2             4.9093      0.582      8.433      0.000       3.768       6.050
# x3             0.9512      0.718      1.324      0.185      -0.456       2.359
# x4           -12.0839      0.927    -13.031      0.000     -13.901     -10.266
# x5            -5.0297      1.010     -4.979      0.000      -7.010      -3.050
# x6            -1.2099      0.592     -2.043      0.041      -2.370      -0.049
# x7            12.3990      0.576     21.525      0.000      11.270      13.528
# x8            20.9281      0.565     37.054      0.000      19.821      22.035
# x9             2.1985      0.561      3.917      0.000       1.098       3.299
# x10           -2.9510      0.707     -4.176      0.000      -4.336      -1.566
# x11           13.0843      0.776     16.856      0.000      11.563      14.606
# x12            9.9574      0.720     13.837      0.000       8.547      11.368
# x13            6.8485      0.561     12.216      0.000       5.750       7.947
# x14           17.3408      0.561     30.924      0.000      16.242      18.440
# x15           26.9452      0.685     39.363      0.000      25.604      28.287
# x16            4.6380      0.885      5.243      0.000       2.904       6.372
# x17          -13.9705      1.013    -13.792      0.000     -15.956     -11.985
# x18           51.0532      1.153     44.280      0.000      48.793      53.313
# x19            2.4490      0.636      3.853      0.000       1.203       3.695
# x20            0.7134      0.632      1.129      0.259      -0.526       1.952
# x21           -4.4341      1.070     -4.142      0.000      -6.532      -2.336
# x22           -1.6319      1.326     -1.231      0.218      -4.230       0.967
# x23           -7.4633      0.581    -12.843      0.000      -8.602      -6.324
# ==============================================================================
# Omnibus:                    29238.208   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           696451.825
# Skew:                           2.474   Prob(JB):                         0.00
# Kurtosis:                      20.900   Cond. No.                         5.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <h1> Model 3

# %%
#Select the features that show the highest correlation & make most sense for predicting premium & run an 
# OLS model on it

X = auto_df_sub[['R_Claims_history', 'Year_matriculation', 'Value_vehicle']]
y = auto_df_sub['Premium']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=47)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled = sm.add_constant(X_train_scaled)
X_test_scaled = sm.add_constant(X_test_scaled)

# %%
print(X_train_scaled)
# Out:
# [[ 1.         -0.6163156  -0.85207402 -0.99077381]
#  [ 1.         -0.6163156   1.83132795 -1.36115702]
#  [ 1.         -0.4901758   0.22128677 -0.62939993]
#  ...
#  [ 1.         -0.6163156   2.01022142  1.28213403]
#  [ 1.         -0.6163156  -1.56764788  0.42357825]
#  [ 1.         -0.6163156   1.83132795  1.3591437 ]]

# %%
model3 = sm.OLS(y_train, X_train_scaled)
model3_res = model3.fit()

model3_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Premium   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     3317.
# Date:                Thu, 05 Sep 2024   Prob (F-statistic):               0.00
# Time:                        10:55:06   Log-Likelihood:            -3.0323e+05
# No. Observations:               48465   AIC:                         6.065e+05
# Df Residuals:                   48461   BIC:                         6.065e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        336.9329      0.573    587.855      0.000     335.810     338.056
# x1            17.5473      0.575     30.523      0.000      16.421      18.674
# x2            34.1942      0.584     58.587      0.000      33.050      35.338
# x3            36.5306      0.584     62.580      0.000      35.386      37.675
# ==============================================================================
# Omnibus:                    28551.400   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           625184.636
# Skew:                           2.420   Prob(JB):                         0.00
# Kurtosis:                      19.916   Cond. No.                         1.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <h1> Model 4

# %%
#lets try using Lasso Regression with the original features included

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
X = auto_df_sub.drop(columns=['Premium'])
y = auto_df_sub['Premium']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=47)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model4 = Lasso(alpha = .141747)
model4.fit(X_train_scaled, y_train)

y_train_pred = model4.predict(X_train_scaled)

training_mse = mean_squared_error(y_train, y_train_pred)
print(np.sqrt(training_mse))
r2 = r2_score(y_train, y_train_pred)
print(r2)
print(training_mse)
# Out:
# 120.60285879332116
# 0.24200478026393057
# 14545.049549121763

# %% [markdown]
# <h1> Model 4.5

# %%
#try implementing GridSearchCV to determine how much it effects the model
from sklearn.model_selection import GridSearchCV

param_grid = {'alpha': np.logspace(-4, 4, 100)}

lasso_mod = Lasso()
grid_search = GridSearchCV(lasso_mod, param_grid, cv=5, scoring='r2')
grid_search.fit(X_train_scaled, y_train)

best_alpha = grid_search.best_params_['alpha']

print(best_alpha)
# Out:
# 0.14174741629268062

# %% [markdown]
# <h1> Model 5 - Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
X = auto_df_sub.drop(columns=['Premium'])
y = auto_df_sub['Premium']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=47)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
param_grid = {'alpha': np.logspace(-4, 4, 100)}

ridge_mod = Ridge()
grid_search = GridSearchCV(ridge_mod, param_grid, cv=5, scoring='r2')
grid_search.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': array([1.00000000e-04, 1.20450354e-04, 1.45082878e-04, 1.74752840e-04,
#        2.10490414e-04, 2.53536449e-04, 3.05385551e-04, 3.67837977e-04,
#        4.43062146e-04, 5.33669923e-04, 6.42807312e-04, 7.74263683e-04,
#        9.32603347e-04, 1.12332403e-03, 1.35304777e-03, 1.62975083e-03,
#        1.96304065e-03, 2.36448941e-03, 2.84803587e-03, 3....
#        1.38488637e+02, 1.66810054e+02, 2.00923300e+02, 2.42012826e+02,
#        2.91505306e+02, 3.51119173e+02, 4.22924287e+02, 5.09413801e+02,
#        6.13590727e+02, 7.39072203e+02, 8.90215085e+02, 1.07226722e+03,
#        1.29154967e+03, 1.55567614e+03, 1.87381742e+03, 2.25701972e+03,
#        2.71858824e+03, 3.27454916e+03, 3.94420606e+03, 4.75081016e+03,
#        5.72236766e+03, 6.89261210e+03, 8.30217568e+03, 1.00000000e+04])},
#              scoring='r2')

# %%
best_alpha = grid_search.best_params_['alpha']
print(best_alpha)
# Out:
# 138.48863713938746

# %%
ridge = Ridge(alpha=138.488)

ridge.fit(X_train_scaled, y_train)
y_train_pred = ridge.predict(X_train_scaled)

print(r2_score(y_train, y_train_pred))
# Out:
# 0.24203347702826417

# %% [markdown]
# <h1> Model 6 - Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X = auto_df_sub.drop(columns=['Premium'])
y = auto_df_sub['Premium']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=40)

rf = RandomForestRegressor(random_state=47, n_estimators=1000)

rf.fit(X_train, y_train)

y_pred_train = rf.predict(X_train)

# %%
mse = mean_squared_error(y_train, y_pred_train)
print(r2_score(y_train, y_pred_train))
print(np.sqrt(mse))
print(mse)
# Out:
# 0.9449953589152541
# 32.35884358115055
# 1047.0947579093684

# %%
y_pred = rf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(r2_score(y_test, y_pred))
print(np.sqrt(mse))
print(mse)
# Out:
# 0.5749065922716776
# 91.74329785083972
# 8416.832700547893

# %% [markdown]
# <h1> Model 6.5 Grid Search with Random Forest Regressor

# %%
X = auto_df_sub.drop(columns=['Premium'])
y = auto_df_sub['Premium']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=45)

param_grid = {'n_estimators' : [100, 200, 300, 500, 1000],
              'max_depth' : [5, 10, 15, 20, 25, 30, None]}

rf_model = RandomForestRegressor()
grid_search = GridSearchCV(rf_model, param_grid, cv=5)

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15, 20, 25, 30, None],
#                          'n_estimators': [100, 200, 300, 500, 1000]})

# %%
best_rf = grid_search.best_estimator_

feature_importances = best_rf.feature_importances_


importance_df = pd.DataFrame({
    'Feature' : X.columns,
    'Importance': feature_importances
})

# Sort by importance
importance_df = importance_df.sort_values(by='Importance', ascending=False)

importance_df
# Out:
#                  Feature  Importance
# 17         Value_vehicle    0.154670
# 14    Year_matriculation    0.128611
# 22                   Age    0.121584
# 0                     ID    0.085314
# 11      R_Claims_history    0.061122
# 21                Weight    0.054609
# 20                Length    0.053521
# 15                 Power    0.048825
# 16     Cylinder_capacity    0.047924
# 2              Seniority    0.042417
# 10      N_claims_history    0.038449
# 7                Payment    0.035794
# 8       Cost_claims_year    0.021196
# 3      Policies_in_force    0.020461
# 13         Second_driver    0.017971
# 4           Max_policies    0.015217
# 6                  Lapse    0.012341
# 1   Distribution_channel    0.010572
# 12                  Area    0.010332
# 9          N_claims_year    0.006840
# 19             Type_fuel    0.004965
# 18               N_doors    0.003895
# 5           Max_products    0.003372

# %%
grid_search.best_params_
# Out:
# {'max_depth': None, 'n_estimators': 1000}

# %%
#Although the best parameters indicate no max_depth and large estimator, I will need to play around with the
#hyperparameters to try and find a good bias-variance trade off without overfitting the model.
#submitting this now but will conitnue to work on this model.
